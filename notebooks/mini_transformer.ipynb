# %%
import sys
import os 
sys.path.append("C:\\Users\\dange\\Desktop\\English-Hindi-Translation")
sys.path
# Out:
# ['C:\\Users\\dange\\AppData\\Roaming\\uv\\python\\cpython-3.12.8-windows-x86_64-none\\python312.zip',
#  'C:\\Users\\dange\\AppData\\Roaming\\uv\\python\\cpython-3.12.8-windows-x86_64-none\\DLLs',
#  'C:\\Users\\dange\\AppData\\Roaming\\uv\\python\\cpython-3.12.8-windows-x86_64-none\\Lib',
#  'C:\\Users\\dange\\AppData\\Roaming\\uv\\python\\cpython-3.12.8-windows-x86_64-none',
#  'c:\\Users\\dange\\Desktop\\English-Hindi-Translation\\.venv',
#  '',
#  'c:\\Users\\dange\\Desktop\\English-Hindi-Translation\\.venv\\Lib\\site-packages',
#  'C:\\Users\\dange\\Desktop\\English-Hindi-Translation']
